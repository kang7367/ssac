# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
series = np.sin(0.1 * np.arange(200)) # + np.random.randn(200) * 0.1 
plt.plot(series)
plt.show()

# %%
series = np.sin(0.1 * np.arange(200)) + np.random.randn(200) * 0.1 
plt.plot(series)
plt.show()

# %%
# build the dataset
T = 10
X = []
Y = []
for t in range(len(series) - T):
    x = series[t:t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

np.array(X).shape
# np.array(Y).shape
# Out:
# (190, 10)

# %%
# sequences data -> N x T x D -> 190 x 10 x 1
X = np.array(X).reshape(-1, T, 1)
Y = np.array(Y)
N = len(X)
print(f"X.shape:{X.shape}, Y.shape:{Y.shape}, N.length:{N}")
# Out:
# X.shape:(190, 10, 1), Y.shape:(190,), N.length:190

# %%
# build a RNN model 
# 1. Input  
i = Input(shape=(T, 1)) # T x D
# 2. SimpleRNN(5, activation='relu')
x = SimpleRNN(5, activation='relu')(i)
# 3. Output 
x = Dense(1)(x)
model = Model(i , x)
model.compile(loss='mse', optimizer=Adam(lr=0.1))
# Quiz. trainable params -> 41 = hidden weights + current weights + bais 
#                              = (features * unit) + (unit * unit) + (feature * unit)
#                              = (1 * 5) + (5 * 5) + (1 * 5) = 35
# Out:
# 2022-03-15 14:18:14.966803: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /opt/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10, 1)]           0
#
#  simple_rnn (SimpleRNN)      (None, 5)                 35
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the RNN
r = model.fit(X[:-N//2], Y[:-N//2], epochs=80, validation_data=(X[-N//2:], Y[-N//2:]))
# Out:
# Epoch 1/80
# 3/3 [==============================] - 1s 88ms/step - loss: 1.1659 - val_loss: 0.6478
# Epoch 2/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5381 - val_loss: 0.4308
# Epoch 3/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3916 - val_loss: 0.2987
# Epoch 4/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2578 - val_loss: 0.2141
# Epoch 5/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1502 - val_loss: 0.2067
# Epoch 6/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1563 - val_loss: 0.2172
# Epoch 7/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1598 - val_loss: 0.1662
# Epoch 8/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1107 - val_loss: 0.1171
# Epoch 9/80
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0825 - val_loss: 0.1057
# Epoch 10/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0831 - val_loss: 0.0862
# Epoch 11/80
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0638 - val_loss: 0.0699
# Epoch 12/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0577 - val_loss: 0.0674
# Epoch 13/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0584 - val_loss: 0.0610
# Epoch 14/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0492 - val_loss: 0.0617
# Epoch 15/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0494 - val_loss: 0.0586
# Epoch 16/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0441 - val_loss: 0.0485
# Epoch 17/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0381 - val_loss: 0.0437
# Epoch 18/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0358 - val_loss: 0.0392
# Epoch 19/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0337 - val_loss: 0.0383
# Epoch 20/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0329 - val_loss: 0.0350
# Epoch 21/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0315 - val_loss: 0.0326
# Epoch 22/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0306 - val_loss: 0.0315
# Epoch 23/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0295 - val_loss: 0.0314
# Epoch 24/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0285 - val_loss: 0.0310
# Epoch 25/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0277 - val_loss: 0.0303
# Epoch 26/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0275 - val_loss: 0.0301
# Epoch 27/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0276 - val_loss: 0.0314
# Epoch 28/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0265 - val_loss: 0.0302
# Epoch 29/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0262 - val_loss: 0.0299
# Epoch 30/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0264 - val_loss: 0.0300
# Epoch 31/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0256 - val_loss: 0.0291
# Epoch 32/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0258 - val_loss: 0.0282
# Epoch 33/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0255 - val_loss: 0.0287
# Epoch 34/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0255 - val_loss: 0.0290
# Epoch 35/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0255 - val_loss: 0.0277
# Epoch 36/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0250 - val_loss: 0.0274
# Epoch 37/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0255 - val_loss: 0.0284
# Epoch 38/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0249 - val_loss: 0.0298
# Epoch 39/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0252 - val_loss: 0.0279
# Epoch 40/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0295 - val_loss: 0.0272
# Epoch 41/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0262 - val_loss: 0.0324
# Epoch 42/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0264 - val_loss: 0.0266
# Epoch 43/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0260 - val_loss: 0.0263
# Epoch 44/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0263 - val_loss: 0.0303
# Epoch 45/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0253 - val_loss: 0.0269
# Epoch 46/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0258 - val_loss: 0.0266
# Epoch 47/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0254 - val_loss: 0.0302
# Epoch 48/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0252 - val_loss: 0.0271
# Epoch 49/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0273 - val_loss: 0.0267
# Epoch 50/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0261 - val_loss: 0.0321
# Epoch 51/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0255 - val_loss: 0.0263
# Epoch 52/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0262 - val_loss: 0.0263
# Epoch 53/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0238 - val_loss: 0.0300
# Epoch 54/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0257 - val_loss: 0.0275
# Epoch 55/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0244 - val_loss: 0.0268
# Epoch 56/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0251 - val_loss: 0.0276
# Epoch 57/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0261 - val_loss: 0.0288
# Epoch 58/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0276 - val_loss: 0.0264
# Epoch 59/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0258 - val_loss: 0.0320
# Epoch 60/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0257 - val_loss: 0.0267
# Epoch 61/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0273 - val_loss: 0.0259
# Epoch 62/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0282 - val_loss: 0.0319
# Epoch 63/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0247 - val_loss: 0.0258
# Epoch 64/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0261 - val_loss: 0.0267
# Epoch 65/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0243 - val_loss: 0.0290
# Epoch 66/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0242 - val_loss: 0.0263
# Epoch 67/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0252 - val_loss: 0.0267
# Epoch 68/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0259 - val_loss: 0.0289
# Epoch 69/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0250 - val_loss: 0.0262
# Epoch 70/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0259 - val_loss: 0.0285
# Epoch 71/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0244 - val_loss: 0.0257
# Epoch 72/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0242 - val_loss: 0.0258
# Epoch 73/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0255 - val_loss: 0.0278
# Epoch 74/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0238 - val_loss: 0.0260
# Epoch 75/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0241 - val_loss: 0.0281
# Epoch 76/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0245 - val_loss: 0.0271
# Epoch 77/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0250 - val_loss: 0.0258
# Epoch 78/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0252 - val_loss: 0.0284
# Epoch 79/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0236 - val_loss: 0.0258
# Epoch 80/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0250 - val_loss: 0.0270

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Wrong forecast using true targets
validation_target = Y[-N//2:]
validation_predictions = []

i = -N//2 

while len(validation_predictions) < len(validation_target):
    p = model.predict(X[i].reshape(1, -1, 1))[0,0]
    i += 1
    
    validation_predictions.append(p)

# %%
plt.plot(validation_target, label='validation_target')
plt.plot(validation_predictions, label='validation_predictions')
plt.legend()

# %%
# Forecast future values
validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X[-N//2]  

while len(validation_predictions) < len(validation_target):
    p = model.predict(last_x.reshape(1, -1, 1))[0,0]
    i += 1
    
    validation_predictions.append(p)
    
    last_x = np.roll(last_x, -1)
#     print(last_x)
    last_x[-1] = p

# %%
plt.plot(validation_target, label='validation_target')
plt.plot(validation_predictions, label='validation_predictions')
plt.legend()
